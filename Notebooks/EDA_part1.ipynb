# %%
import os
import requests
import pandas as pd
import json
from datetime import datetime, timedelta
import time
from pandas.plotting import scatter_matrix

import glob

# %% [markdown]
# # Loading Data

# %% [markdown]
# Loading data from multiple json sources into one pandas Dataframe

# %%
path = r'../endlessdice-201903' # use your path
all_files = glob.glob(path + "/*.json")

li = []

for filename in all_files:
    df = pd.read_json(filename,lines=True)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True,sort=True)

# %%
frame=pd.read_csv()

# %%
frame.shape
# Out:
# (4762541, 16)

# %% [markdown]
# ## EDA

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4762541 entries, 0 to 4762540
# Data columns (total 16 columns):
# account               object
# account_action_seq    int64
# authorization         object
# block_num             int64
# d_from                object
# d_memo                object
# d_quantity            float64
# d_quantity_unit       object
# d_to                  object
# dapp_code             object
# data                  object
# global_action_seq     int64
# name                  object
# trx_id                object
# trx_timestamp         object
# trx_timestamp_unix    float64
# dtypes: float64(2), int64(3), object(11)
# memory usage: 581.4+ MB

# %% [markdown]
# Looking at numerical features of data to understand distribution. It seems d_quantity will be the only useful metric from understanding of the features provided in our data description file

# %%
frame.describe()
# Out:
#        account_action_seq     block_num    d_quantity  global_action_seq  \
# count        4.762541e+06  4.762541e+06  4.762537e+06       4.762541e+06
# mean         4.302966e+06  4.791605e+07  9.627010e-01       5.611532e+09
# std          1.956884e+06  1.558004e+06  4.173186e+01       1.661785e+08
# min          1.284860e+06  4.523276e+07  8.000000e-07       5.326755e+09
# 25%          2.475495e+06  4.657030e+07  2.400000e-03       5.469543e+09
# 50%          4.232553e+06  4.789780e+07  9.800000e-02       5.608729e+09
# 75%          6.018499e+06  4.930079e+07  1.960000e-01       5.756417e+09
# max          7.804443e+06  5.058461e+07  2.236003e+04       5.907187e+09
#
#        trx_timestamp_unix
# count        4.762541e+06
# mean         1.552741e+09
# std          7.797664e+05
# min          1.551398e+09
# 25%          1.552068e+09
# 50%          1.552732e+09
# 75%          1.553434e+09
# max          1.554077e+09

# %% [markdown]
# How many unique accounts are there and how many transactions do each of them do?

# %%
frame['d_from'].value_counts()
# Out:
# endlessdicex    3048248
# endlessbank1     776259
# nmslnmslnmsl     254893
# eossuperplay     202279
# endlesscrash     175291
# bimawen11111      17832
# thegrintsch1      14983
# kaidenmatias      14179
# g4ztemjugyge      12963
# everettlayne      12767
# andrewcortez      12459
# ticklish2424      11152
# skdi12312311       9662
# danieldamari       9164
# adawalletwin       8151
# stardlullaby       7464
# xuminggangok       7450
# twinswallet1       6344
# g44temrwgage       5922
# g44dmnrxg4ge       5791
# iyeoseos1eee       5453
# leiniao12345       4887
# asdfghjklz14       4799
# wobuzhidaoya       4425
# benzilimbenb       3981
# gy3tamrxgqge       3838
# zahuhuo1o1o2       3635
# xulingbookok       3463
# gyydinbrgige       3247
# ge4tinrzhage       2975
#                  ...
# jonathankoch          1
# soowangkilky          1
# hazdsmrwgqge          1
# wosdateos154          1
# thecoinusio3          1
# jxjdsidsijsk          1
# eosers.x              1
# seabattlemem          1
# wenzhenxiang          1
# zhujinyong11          1
# bearjie12345          1
# prauwl5qabyx          1
# shaoxing2222          1
# hchn12345432          1
# quddhksss123          1
# airdropworkr          1
# superuser525          1
# wangqingxia1          1
# loveeoschina          1
# beniiiiiiiii          1
# firstclubeos          1
# nccccccccccn          1
# 12345wszyxxx          1
# gameswitcher          1
# helaclhch224          1
# erostoken111          1
# dscoinseven2          1
# neverend1234          1
# suttoken1314          1
# shensicong53          1
# Name: d_from, Length: 1667, dtype: int64

# %% [markdown]
# Over the 1667 accounts, there is pretty non-uniform distribution with a heavy tail of accounts with only one transaction. Perhaps all of the single transaction accounts can be bots?

# %%
frame.head(10)
# Out:
#        account  account_action_seq  \
# 0  eosio.token             4092172
# 1  eosio.token             4092173
# 2  eosio.token             4092174
# 3  eosio.token             4092175
# 4  eosio.token             4092176
# 5  eosio.token             4092177
# 6  eosio.token             4092179
# 7  eosio.token             4092181
# 8  eosio.token             4092182
# 9  eosio.token             4092184
#
#                                        authorization  block_num        d_from  \
# 0  [{'actor': 'justiceariel', 'permission': 'acti...   46268353  justiceariel
# 1  [{'actor': 'eossuperplay', 'permission': 'acti...   46268355  eossuperplay
# 2  [{'actor': 'nmslnmslnmsl', 'permission': 'acti...   46268358  nmslnmslnmsl
# 3  [{'actor': 'edgarwinston', 'permission': 'acti...   46268360  edgarwinston
# 4  [{'actor': 'raidenkeegan', 'permission': 'acti...   46268366  raidenkeegan
# 5  [{'actor': 'endlessdicex', 'permission': 'acti...   46268370  endlessdicex
# 6  [{'actor': 'endlessdicex', 'permission': 'acti...   46268370  endlessdicex
# 7  [{'actor': 'endlessdicex', 'permission': 'acti...   46268370  endlessdicex
# 8  [{'actor': 'endlessdicex', 'permission': 'acti...   46268370  endlessdicex
# 9  [{'actor': 'endlessdicex', 'permission': 'acti...   46268370  endlessdicex
#
#                                               d_memo  d_quantity  \
# 0  96-5db37a4363ab3ea2bec1ebc2858ffb4a8e39648d3ba...      0.1000
# 1  96-a61d1f367685a2aa8b1da4b78ade17e166e5be9d256...      0.1000
# 2  96-db123609ce06d9da8ed163a15babe723ee6a6944a11...      0.2000
# 3  96-4cb99f6c294c85e824f1668f790608f6a90d003ec58...      0.1000
# 4  96-8cde107767044401cb03912b9464a9af653c8e1ccaa...      0.1000
# 5  bet id:13612230 player: edgarwinston send to b...      0.0980
# 6  bet id:13612230 player: edgarwinston dividend ...      0.0008
# 7  bet id:13612230 player: edgarwinston send to c...      0.0012
# 8  bet id:13612231 player: raidenkeegan send to b...      0.0980
# 9  bet id:13612231 player: raidenkeegan dividend ...      0.0008
#
#   d_quantity_unit          d_to     dapp_code data  global_action_seq  \
# 0             EOS  endlessdicex  Endless Dice  NaN         5437311955
# 1             EOS  endlessdicex  Endless Dice  NaN         5437312292
# 2             EOS  endlessdicex  Endless Dice  NaN         5437313093
# 3             EOS  endlessdicex  Endless Dice  NaN         5437313534
# 4             EOS  endlessdicex  Endless Dice  NaN         5437314911
# 5             EOS  endlessbank1  Endless Dice  NaN         5437315482
# 6             EOS  endlessdivdn  Endless Dice  NaN         5437315485
# 7             EOS  endlessoptex  Endless Dice  NaN         5437315488
# 8             EOS  endlessbank1  Endless Dice  NaN         5437315499
# 9             EOS  endlessdivdn  Endless Dice  NaN         5437315502
#
#        name                                             trx_id  \
# 0  transfer  1a67bec15c41f19a16c52095484179da52f99954c7666b...
# 1  transfer  9dba0bbf8240c888f69eae8479705fa0be5c40de7eaeab...
# 2  transfer  a6ab394b9d2a5f29d4ab55d5015ae102f0da0726449bfd...
# 3  transfer  adfc46a0bc27b1347a9636756728e4bdecce28bf601bc6...
# 4  transfer  d68cdfa9bd39d2f6fcdabaf37439cdbb24f2f9f55f4670...
# 5  transfer  a67cb0f4106d1fe4facb695828de02b231ade8238991f3...
# 6  transfer  a67cb0f4106d1fe4facb695828de02b231ade8238991f3...
# 7  transfer  a67cb0f4106d1fe4facb695828de02b231ade8238991f3...
# 8  transfer  a67cb0f4106d1fe4facb695828de02b231ade8238991f3...
# 9  transfer  a67cb0f4106d1fe4facb695828de02b231ade8238991f3...
#
#              trx_timestamp  trx_timestamp_unix
# 0  2019-03-07T00:00:02.000        1.551917e+09
# 1  2019-03-07T00:00:03.000        1.551917e+09
# 2  2019-03-07T00:00:04.500        1.551917e+09
# 3  2019-03-07T00:00:06.000        1.551917e+09
# 4  2019-03-07T00:00:09.000        1.551917e+09
# 5  2019-03-07T00:00:11.000        1.551917e+09
# 6  2019-03-07T00:00:11.000        1.551917e+09
# 7  2019-03-07T00:00:11.000        1.551917e+09
# 8  2019-03-07T00:00:11.000        1.551917e+09
# 9  2019-03-07T00:00:11.000        1.551917e+09

# %%
frame['d_from'].value_counts()[frame['d_from'].value_counts()>1000]
# Out:
# endlessdicex    3048248
# endlessbank1     776259
# nmslnmslnmsl     254893
# eossuperplay     202279
# endlesscrash     175291
# bimawen11111      17832
# thegrintsch1      14983
# kaidenmatias      14179
# g4ztemjugyge      12963
# everettlayne      12767
# andrewcortez      12459
# ticklish2424      11152
# skdi12312311       9662
# danieldamari       9164
# adawalletwin       8151
# stardlullaby       7464
# xuminggangok       7450
# twinswallet1       6344
# g44temrwgage       5922
# g44dmnrxg4ge       5791
# iyeoseos1eee       5453
# leiniao12345       4887
# asdfghjklz14       4799
# wobuzhidaoya       4425
# benzilimbenb       3981
# gy3tamrxgqge       3838
# zahuhuo1o1o2       3635
# xulingbookok       3463
# gyydinbrgige       3247
# ge4tinrzhage       2975
# babybaby3355       2787
# zzxzzxzzxzzx       2745
# lt5555lt5555       2685
# gu3domagenes       2496
# perolehsitos       2041
# gu3dsnbqhege       1879
# azxsdcvf1111       1794
# gi4tqnbrgene       1740
# eostxleos111       1739
# gu2dcmjqgqge       1721
# 55113335hgqu       1692
# txltxltxl111       1567
# eoswalletios       1512
# huhaibinplus       1510
# abcloveu1314       1488
# eosman53yong       1375
# meetone12122       1368
# eostokenzhen       1354
# adssg3451122       1313
# yaohang12345       1248
# indiemusic55       1244
# muhamadaddin       1132
# bansheecobbb       1063
# yqqlmgsycl55       1006
# Name: d_from, dtype: int64

# %% [markdown]
# ## Initial PreProcessing for EDA

# %% [markdown]
# Make a timestamp object to explore timeseries data

# %%
def strpDateTime(data):
    return data['trx_timestamp'].apply(lambda x : datetime.strptime(x[:10]+x[11:19],"%Y-%m-%d%H:%M:%S"))

# %% [markdown]
# Drop cols which are deemed useless based on feature understanding

# %%
def dropcols(data):
    #d_memo and maybe block_num may have some relevance later on
    return data.drop(['account_action_seq','block_num','d_memo','authorization','global_action_seq','data','name','trx_id','trx_timestamp_unix'],axis=1)

# %% [markdown]
# These are the labels which were given to us by our Advisor, creating a function to label them

# %%
def applyLabels(data):
    list_bots=['edgarwinston','Griffinhamza','jacksonjimmy','1ffyqhg4rmbk','1ffyqhg4rmbk','powellernest','2rezoaf4bhly','nckj42dit5sb','scottphillip','oepa252sdx4p','myh2o4wayvxg']
    list_humans=['g44dinjygene','onebrother11','rvrkingfishr','iloveyoudapp','huiyong12345','pketothemoon','zhshj1212123','vipgamedice2','dldldldldldl','pkeniubixxxx']
    data['bot_label']=data['d_from'].apply(lambda x: 1 if x in list_bots else (0 if x in list_humans else None))

# %% [markdown]
# Aggregate dataprocessing function

# %%
def dataprocess(data):
    data['trx_timestamp']=strpDateTime(frame)
    applyLabels(data)
    return dropcols(data)

# %%
clean_frame=dataprocess(frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-152831b0c19a> in <module>
# ----> 1 clean_frame=dataprocess(frame)
#
# NameError: name 'frame' is not defined

# %%
clean_frame
# Out:
#              account        d_from  d_quantity d_quantity_unit          d_to  \
# 0        eosio.token  justiceariel      0.1000             EOS  endlessdicex
# 1        eosio.token  eossuperplay      0.1000             EOS  endlessdicex
# 2        eosio.token  nmslnmslnmsl      0.2000             EOS  endlessdicex
# 3        eosio.token  edgarwinston      0.1000             EOS  endlessdicex
# 4        eosio.token  raidenkeegan      0.1000             EOS  endlessdicex
# 5        eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 6        eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 7        eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 8        eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 9        eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 10       eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 11       eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 12       eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 13       eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 14       eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 15       eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 16       eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 17       eosio.token  endlessdicex      0.1960             EOS  endlessbank1
# 18       eosio.token  endlessdicex      0.0016             EOS  endlessdivdn
# 19       eosio.token  endlessdicex      0.0024             EOS  endlessoptex
# 20       eosio.token  heathderrick      0.1000             EOS  endlessdicex
# 21       eosio.token  eossuperplay      0.1000             EOS  endlessdicex
# 22       eosio.token  nmslnmslnmsl      0.2000             EOS  endlessdicex
# 23       eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 24       eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 25       eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 26       eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 27       eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 28       eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 29       eosio.token  jakobantoine      0.1000             EOS  endlessdicex
# ...              ...           ...         ...             ...           ...
# 4762511  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762512  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 4762513  eosio.token  eossuperplay      0.1000             EOS  endlessdicex
# 4762514  eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 4762515  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762516  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 4762517  eosio.token  nmslnmslnmsl      0.1000             EOS  endlessdicex
# 4762518  eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 4762519  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762520  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 4762521  eosio.token  eossuperplay      0.1000             EOS  endlessdicex
# 4762522  eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 4762523  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762524  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 4762525  eosio.token  nmslnmslnmsl      0.1000             EOS  endlessdicex
# 4762526  eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 4762527  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762528  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 4762529  eosio.token  eossuperplay      0.1000             EOS  endlessdicex
# 4762530  eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 4762531  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762532  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 4762533  eosio.token  nmslnmslnmsl      0.1000             EOS  endlessdicex
# 4762534  eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 4762535  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762536  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
# 4762537  eosio.token  eossuperplay      0.1000             EOS  endlessdicex
# 4762538  eosio.token  endlessdicex      0.0980             EOS  endlessbank1
# 4762539  eosio.token  endlessdicex      0.0008             EOS  endlessdivdn
# 4762540  eosio.token  endlessdicex      0.0012             EOS  endlessoptex
#
#             dapp_code       trx_timestamp  bot_label
# 0        Endless Dice 2019-03-07 00:00:02        NaN
# 1        Endless Dice 2019-03-07 00:00:03        NaN
# 2        Endless Dice 2019-03-07 00:00:04        NaN
# 3        Endless Dice 2019-03-07 00:00:06        1.0
# 4        Endless Dice 2019-03-07 00:00:09        NaN
# 5        Endless Dice 2019-03-07 00:00:11        NaN
# 6        Endless Dice 2019-03-07 00:00:11        NaN
# 7        Endless Dice 2019-03-07 00:00:11        NaN
# 8        Endless Dice 2019-03-07 00:00:11        NaN
# 9        Endless Dice 2019-03-07 00:00:11        NaN
# 10       Endless Dice 2019-03-07 00:00:11        NaN
# 11       Endless Dice 2019-03-07 00:00:11        NaN
# 12       Endless Dice 2019-03-07 00:00:11        NaN
# 13       Endless Dice 2019-03-07 00:00:11        NaN
# 14       Endless Dice 2019-03-07 00:00:11        NaN
# 15       Endless Dice 2019-03-07 00:00:11        NaN
# 16       Endless Dice 2019-03-07 00:00:11        NaN
# 17       Endless Dice 2019-03-07 00:00:11        NaN
# 18       Endless Dice 2019-03-07 00:00:11        NaN
# 19       Endless Dice 2019-03-07 00:00:11        NaN
# 20       Endless Dice 2019-03-07 00:00:13        NaN
# 21       Endless Dice 2019-03-07 00:00:13        NaN
# 22       Endless Dice 2019-03-07 00:00:15        NaN
# 23       Endless Dice 2019-03-07 00:00:15        NaN
# 24       Endless Dice 2019-03-07 00:00:15        NaN
# 25       Endless Dice 2019-03-07 00:00:15        NaN
# 26       Endless Dice 2019-03-07 00:00:15        NaN
# 27       Endless Dice 2019-03-07 00:00:15        NaN
# 28       Endless Dice 2019-03-07 00:00:15        NaN
# 29       Endless Dice 2019-03-07 00:00:16        NaN
# ...               ...                 ...        ...
# 4762511  Endless Dice 2019-03-28 23:59:23        NaN
# 4762512  Endless Dice 2019-03-28 23:59:23        NaN
# 4762513  Endless Dice 2019-03-28 23:59:23        NaN
# 4762514  Endless Dice 2019-03-28 23:59:26        NaN
# 4762515  Endless Dice 2019-03-28 23:59:26        NaN
# 4762516  Endless Dice 2019-03-28 23:59:26        NaN
# 4762517  Endless Dice 2019-03-28 23:59:32        NaN
# 4762518  Endless Dice 2019-03-28 23:59:33        NaN
# 4762519  Endless Dice 2019-03-28 23:59:33        NaN
# 4762520  Endless Dice 2019-03-28 23:59:33        NaN
# 4762521  Endless Dice 2019-03-28 23:59:34        NaN
# 4762522  Endless Dice 2019-03-28 23:59:36        NaN
# 4762523  Endless Dice 2019-03-28 23:59:36        NaN
# 4762524  Endless Dice 2019-03-28 23:59:36        NaN
# 4762525  Endless Dice 2019-03-28 23:59:42        NaN
# 4762526  Endless Dice 2019-03-28 23:59:43        NaN
# 4762527  Endless Dice 2019-03-28 23:59:43        NaN
# 4762528  Endless Dice 2019-03-28 23:59:43        NaN
# 4762529  Endless Dice 2019-03-28 23:59:44        NaN
# 4762530  Endless Dice 2019-03-28 23:59:46        NaN
# 4762531  Endless Dice 2019-03-28 23:59:46        NaN
# 4762532  Endless Dice 2019-03-28 23:59:46        NaN
# 4762533  Endless Dice 2019-03-28 23:59:52        NaN
# 4762534  Endless Dice 2019-03-28 23:59:53        NaN
# 4762535  Endless Dice 2019-03-28 23:59:53        NaN
# 4762536  Endless Dice 2019-03-28 23:59:53        NaN
# 4762537  Endless Dice 2019-03-28 23:59:54        NaN
# 4762538  Endless Dice 2019-03-28 23:59:56        NaN
# 4762539  Endless Dice 2019-03-28 23:59:56        NaN
# 4762540  Endless Dice 2019-03-28 23:59:56        NaN
#
# [4762541 rows x 8 columns]

# %% [markdown]
# ## Labeled Bots and Humans in Training Data

# %% [markdown]
# Let's see how many bots and humans there are in our data!

# %%
list_bots=['edgarwinston','Griffinhamza','jacksonjimmy','1ffyqhg4rmbk','1ffyqhg4rmbk','powellernest','2rezoaf4bhly','nckj42dit5sb','scottphillip','oepa252sdx4p','myh2o4wayvxg']
list_humans=['g44dinjygene','onebrother11','rvrkingfishr','iloveyoudapp','huiyong12345','pketothemoon','zhshj1212123','vipgamedice2','dldldldldldl','pkeniubixxxx']

# %%
training_bots= clean_frame[pd.DataFrame(clean_frame['d_from'].to_list()).isin(list_bots).any(1)]
training_bots
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9d1d8f33bd27> in <module>
# ----> 1 training_bots= clean_frame[pd.DataFrame(clean_frame['d_from'].to_list()).isin(list_bots).any(1)]
#       2 training_bots
#
# NameError: name 'clean_frame' is not defined

# %% [markdown]
# ### There are zero labeled humans in our given data! - This is an issue looks like we will have to label a lot more data

# %%
training_bots['d_from'].value_counts()
# Out:
# 1ffyqhg4rmbk    32
# nckj42dit5sb    32
# edgarwinston    31
# Name: d_from, dtype: int64

# %% [markdown]
# Only 3 bots with 95 transactions total

# %%
training_bots['d_quantity'].value_counts()
# Out:
# 0.1    95
# Name: d_quantity, dtype: int64

# %% [markdown]
# Interestingly all of the bot labeled transactions have 0.1 EOS

# %% [markdown]
# ### All bots trade 0.1 d_quantity per transaction - Baseline heuristic? - Advisor says no just a coincidence
